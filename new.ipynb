# %%
import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Traffic_Violations_montgomery_county.csv')

# %%
df.head()
# Out:
#                                   SeqID Date Of Stop Time Of Stop Agency  \
# 0  fbc324ab-bc8d-4743-ba23-7f9f370005e1   08/11/2019     20:02:00    MCP
# 1  a6d904ec-d666-4bc3-8984-f37a4b31854d   08/12/2019     13:41:00    MCP
# 2  54a64f6a-df28-4b65-a335-08883866aa46   08/12/2019     21:00:00    MCP
# 3  cf5479b6-9bc7-4216-a7b2-99e57ae932af   08/12/2019     21:43:00    MCP
# 4  5601ca35-8ee7-4f8e-9208-d89cde96d469   08/12/2019     21:30:00    MCP
#
#                   SubAgency  \
# 0    2nd District, Bethesda
# 1    2nd District, Bethesda
# 2  5th District, Germantown
# 3  5th District, Germantown
# 4    2nd District, Bethesda
#
#                                          Description  \
# 0  LEAVING UNATTENDED VEH. W/O STOPPING ENGINE, L...
# 1  EXCEEDING POSTED MAXIMUM SPEED LIMIT: 85 MPH I...
# 2  DRIVING VEH W/ TV-TYPE RECEIVING VIDEO EQUIP T...
# 3  DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGI...
# 4  FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION O...
#
#                       Location   Latitude  Longitude Accident  ...  \
# 0    CORDELL ST @ NORFOLK AVE.  38.989743 -77.097770       No  ...
# 1     NBI270 AT MIDDLEBROOK RD  39.174110 -77.246170       No  ...
# 2           MIDDLEBROOK AN 355  39.182015 -77.238221       No  ...
# 3  GERMANTOWN RD AND ALE HOUSE  39.160508 -77.284023       No  ...
# 4                EASTWEST/ 355  38.984247 -77.090548       No  ...
#
#        Charge                 Article Contributed To Accident   Race Gender  \
# 0  21-1101(a)  Transportation Article                   False  BLACK      M
# 1    21-801.1  Transportation Article                   False  WHITE      M
# 2     21-1129  Transportation Article                   False  BLACK      M
# 3   13-401(h)  Transportation Article                   False  BLACK      M
# 4   16-116(a)  Transportation Article                   False  BLACK      M
#
#      Driver City Driver State DL State        Arrest Type  \
# 0  SILVER SPRING           MD       MD  A - Marked Patrol
# 1  SILVER SPRING           MD       MD  A - Marked Patrol
# 2   GAITHERSBURG           MD       MD  A - Marked Patrol
# 3     GERMANTOWN           MD       MD  A - Marked Patrol
# 4  SILVER SPRING           MD       MD  A - Marked Patrol
#
#                              Geolocation
# 0          (38.9897433333333, -77.09777)
# 1                  (39.17411, -77.24617)
# 2        (39.1820155, -77.2382213333333)
# 3         (39.1605076666667, -77.284023)
# 4  (38.9842466666667, -77.0905483333333)
#
# [5 rows x 43 columns]

# %%
df['Date Of Stop'] = pd.to_datetime(df['Date Of Stop'])
df.set_index('Date Of Stop', inplace=True)
df.sort_index(inplace=True)
df.head()
# Out:
#                                              SeqID Time Of Stop Agency  \
# Date Of Stop
# 2012-01-01    399e8f6b-eff8-4375-94c8-5eb9aca4be84     03:05:00    MCP
# 2012-01-01    399e8f6b-eff8-4375-94c8-5eb9aca4be84     03:05:00    MCP
# 2012-01-01    e34ef444-6d38-46cb-b9ad-db12895e3db4     06:51:00    MCP
# 2012-01-01    6910a1a8-b428-4b9e-9609-d90e0fd9d6c0     15:07:00    MCP
# 2012-01-01    877ab706-245f-4c93-951f-4cdca7593b20     07:07:00    MCP
#
#                                 SubAgency  \
# Date Of Stop
# 2012-01-01       5th District, Germantown
# 2012-01-01       5th District, Germantown
# 2012-01-01       5th District, Germantown
# 2012-01-01    3rd District, Silver Spring
# 2012-01-01          4th District, Wheaton
#
#                                                     Description  \
# Date Of Stop
# 2012-01-01    EXCEEDING MAXIMUM SPEED: 83 MPH IN A POSTED 55...
# 2012-01-01    DRIVING MOTOR VEH. WHILE LIC. SUSPENDED UNDER ...
# 2012-01-01    EXCEEDING MAXIMUM SPEED: 68 MPH IN A POSTED 40...
# 2012-01-01    DRIVING  MOTOR VEHICLE ON HIGHWAY WITHOUT REQU...
# 2012-01-01    FAILING TO SECURE CHILD UNDER AGE 8 IN CHILD S...
#
#                                       Location   Latitude  Longitude Accident  \
# Date Of Stop
# 2012-01-01    INNER LOOPE 495 @ WISCONSION AVE  39.070832 -77.162599       No
# 2012-01-01    INNER LOOPE 495 @ WISCONSION AVE  39.070832 -77.162599       No
# 2012-01-01          N/B RIDGE ROAD @ PREAKNESS  39.259741 -77.222598       No
# 2012-01-01                      I 495 & RT 355  39.017187 -77.109724       No
# 2012-01-01                    S/B 27 @ SKYLARK  39.232463 -77.237458       No
#
#              Belts  ...       Charge                 Article  \
# Date Of Stop        ...
# 2012-01-01      No  ...     21-801.1  Transportation Article
# 2012-01-01      No  ...    16-303(h)  Transportation Article
# 2012-01-01      No  ...     21-801.1  Transportation Article
# 2012-01-01      No  ...    16-101(a)  Transportation Article
# 2012-01-01      No  ...  22-412.2(d)  Transportation Article
#
#              Contributed To Accident      Race Gender  Driver City  \
# Date Of Stop
# 2012-01-01                     False     WHITE      M    ROCKVILLE
# 2012-01-01                     False     WHITE      M    ROCKVILLE
# 2012-01-01                     False     OTHER      F     DAMASCUS
# 2012-01-01                     False  HISPANIC      M  HYATTSVILLE
# 2012-01-01                     False     WHITE      F   CLARKSBURG
#
#              Driver State DL State        Arrest Type  \
# Date Of Stop
# 2012-01-01             MD       MD   Q - Marked Laser
# 2012-01-01             MD       MD   Q - Marked Laser
# 2012-01-01             MD       MD  A - Marked Patrol
# 2012-01-01             MD       XX  A - Marked Patrol
# 2012-01-01             MD       MD  A - Marked Patrol
#
#                                         Geolocation
# Date Of Stop
# 2012-01-01          (39.0708319, -77.1625988666667)
# 2012-01-01          (39.0708319, -77.1625988666667)
# 2012-01-01                (39.2597409, -77.2225984)
# 2012-01-01    (39.0171865666667, -77.1097237166667)
# 2012-01-01          (39.2324630166667, -77.2374579)
#
# [5 rows x 42 columns]

# %%
df['year'] = df.index.strftime('%Y')

# %%
sns.histplot(df.year)
# Out:
# <AxesSubplot:xlabel='year', ylabel='Count'>

# %%
df['month'] = df.index.strftime('%B')
df['day_of_week'] = df.index.strftime('%A')

# %%
sns.histplot(df.day_of_week)
# Out:
# <AxesSubplot:xlabel='day_of_week', ylabel='Count'>

# %%
sns.histplot(df.month)
# Out:
# <AxesSubplot:xlabel='month', ylabel='Count'>

# %%
df.isnull().sum()
# Out:
# SeqID                            0
# Time Of Stop                     0
# Agency                           0
# SubAgency                        0
# Description                     10
# Location                         2
# Latitude                         0
# Longitude                        0
# Accident                         0
# Belts                            0
# Personal Injury                  0
# Property Damage                  0
# Fatal                            0
# Commercial License               0
# HAZMAT                           0
# Commercial Vehicle               0
# Alcohol                          0
# Work Zone                        0
# Search Conducted            684511
# Search Disposition         1723276
# Search Outcome              703739
# Search Reason              1723276
# Search Reason For Stop      684743
# Search Type                1723284
# Search Arrest Reason       1748514
# State                           59
# VehicleType                      0
# Year                         10274
# Make                            67
# Model                          212
# Color                        20761
# Violation Type                   0
# Charge                           0
# Article                      83820
# Contributed To Accident          0
# Race                             0
# Gender                           0
# Driver City                    418
# Driver State                    11
# DL State                       929
# Arrest Type                      0
# Geolocation                      0
# year                             0
# month                            0
# day_of_week                      0
# dtype: int64
